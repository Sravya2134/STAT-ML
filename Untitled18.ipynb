# %%
import pandas as pd
d= pd.read_csv('/content/Population GP.csv')
print(d)
# Out:
#      Country  Area_km  Population  Pop_Density  Yearly_Change  \
# 0          1       30      649335        21645           1.39
# 1          2      700     5850342         8358           0.79
# 2          3     1050     7496981         7140           0.82
# 3          4      760     1701575         2239           3.68
# 4          5      300      540544         1802           1.81
# ..       ...      ...         ...          ...            ...
# 196      197   100250      341243            3           0.65
# 197      198  1553560     3278290            2           1.65
# 198      199    62200     1886198           30          -1.08
# 199      200    62674     2722289           43          -1.35
# 200      201     8870     2860853          323          -2.47
#
#      One_Year_Prediction  Density_One_Year  Ten_Year_Prediction  \
# 0                 658361             21945               739593
# 1                5896560              8424              6312519
# 2                7558456              7199              8111733
# 3                1764193              2321              2327755
# 4                 550328              1834               638382
# ..                   ...               ...                  ...
# 196               343461                 3               363424
# 197              3332382                 2              3819208
# 198              1865827                30              1682489
# 199              2685538                43              2354780
# 200              2790190               315              2154222
#
#      Density_Ten_Year  One_Hundred_Year_Prediction  Density_One_Hundred_Year
# 0               24653                      1551911                     51730
# 1                9018                     10472112                     14960
# 2                7725                     13644505                     12995
# 3                3063                      7963371                     10478
# 4                2128                      1518929                      5063
# ..                ...                          ...                       ...
# 196                 4                       563051                         6
# 197                 2                      8687469                         6
# 198                27                      -150896                        -2
# 199                38                      -952801                       -15
# 200               243                     -4205454                      -474
#
# [201 rows x 11 columns]

# %%
df=pd.read_csv('/content/Population GP.csv')
print(df.isnull())
df=df.fillna(0)
# Out:
#      Country  Area_km  Population  Pop_Density  Yearly_Change  \
# 0      False    False       False        False          False
# 1      False    False       False        False          False
# 2      False    False       False        False          False
# 3      False    False       False        False          False
# 4      False    False       False        False          False
# ..       ...      ...         ...          ...            ...
# 196    False    False       False        False          False
# 197    False    False       False        False          False
# 198    False    False       False        False          False
# 199    False    False       False        False          False
# 200    False    False       False        False          False
#
#      One_Year_Prediction  Density_One_Year  Ten_Year_Prediction  \
# 0                  False             False                False
# 1                  False             False                False
# 2                  False             False                False
# 3                  False             False                False
# 4                  False             False                False
# ..                   ...               ...                  ...
# 196                False             False                False
# 197                False             False                False
# 198                False             False                False
# 199                False             False                False
# 200                False             False                False
#
#      Density_Ten_Year  One_Hundred_Year_Prediction  Density_One_Hundred_Year
# 0               False                        False                     False
# 1               False                        False                     False
# 2               False                        False                     False
# 3               False                        False                     False
# 4               False                        False                     False
# ..                ...                          ...                       ...
# 196             False                        False                     False
# 197             False                        False                     False
# 198             False                        False                     False
# 199             False                        False                     False
# 200             False                        False                     False
#
# [201 rows x 11 columns]

# %%
df.head()
# Out:
#    Country  Area_km  Population  Pop_Density  Yearly_Change  \
# 0        1       30      649335        21645           1.39
# 1        2      700     5850342         8358           0.79
# 2        3     1050     7496981         7140           0.82
# 3        4      760     1701575         2239           3.68
# 4        5      300      540544         1802           1.81
#
#    One_Year_Prediction  Density_One_Year  Ten_Year_Prediction  \
# 0               658361             21945               739593
# 1              5896560              8424              6312519
# 2              7558456              7199              8111733
# 3              1764193              2321              2327755
# 4               550328              1834               638382
#
#    Density_Ten_Year  One_Hundred_Year_Prediction  Density_One_Hundred_Year
# 0             24653                      1551911                     51730
# 1              9018                     10472112                     14960
# 2              7725                     13644505                     12995
# 3              3063                      7963371                     10478
# 4              2128                      1518929                      5063

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      201 non-null    int64
#  1   Area_km                      201 non-null    int64
#  2   Population                   201 non-null    int64
#  3   Pop_Density                  201 non-null    int64
#  4   Yearly_Change                201 non-null    float64
#  5   One_Year_Prediction          201 non-null    int64
#  6   Density_One_Year             201 non-null    int64
#  7   Ten_Year_Prediction          201 non-null    int64
#  8   Density_Ten_Year             201 non-null    int64
#  9   One_Hundred_Year_Prediction  201 non-null    int64
#  10  Density_One_Hundred_Year     201 non-null    int64
# dtypes: float64(1), int64(10)
# memory usage: 17.4 KB

# %%
df.describe()
# Out:
#           Country       Area_km    Population   Pop_Density  Yearly_Change  \
# count  201.000000  2.010000e+02  2.010000e+02    201.000000     201.000000
# mean   101.000000  6.450903e+05  3.877661e+07    361.711443       1.200299
# std     58.167861  1.809408e+06  1.454245e+08   1710.321831       1.091574
# min      1.000000  3.000000e+01  9.792900e+04      2.000000      -2.470000
# 25%     51.000000  2.164000e+04  1.886198e+06     34.000000       0.420000
# 50%    101.000000  1.085600e+05  8.654622e+06     89.000000       1.080000
# 75%    151.000000  4.988000e+05  2.769102e+07    228.000000       1.960000
# max    201.000000  1.637687e+07  1.439324e+09  21645.000000       3.840000
#
#        One_Year_Prediction  Density_One_Year  Ten_Year_Prediction  \
# count         2.010000e+02        201.000000         2.010000e+02
# mean          3.918842e+07        365.895522         4.289466e+07
# std           1.464647e+08       1732.336773         1.559462e+08
# min           9.875200e+04          2.000000         1.028590e+05
# 25%           1.865827e+06         35.000000         2.081017e+06
# 50%           8.702422e+06         90.000000         9.418842e+06
# 75%           2.835632e+07        233.000000         3.350200e+07
# max           1.444937e+09      21945.000000         1.516625e+09
#
#        Density_Ten_Year  One_Hundred_Year_Prediction  Density_One_Hundred_Year
# count        201.000000                 2.010000e+02                201.000000
# mean         403.681592                 7.995704e+07                781.597015
# std         1931.736873                 2.575744e+08               3963.575472
# min            2.000000                -4.205454e+06               -474.000000
# 25%           38.000000                 2.120553e+06                 58.000000
# 50%          103.000000                 1.635368e+07                175.000000
# 75%          248.000000                 7.133267e+07                401.000000
# max        24653.000000                 2.746209e+09              51730.000000

# %%
df.columns
# Out:
# Index(['Country', 'Area_km', 'Population', 'Pop_Density', 'Yearly_Change',
#        'One_Year_Prediction', 'Density_One_Year', 'Ten_Year_Prediction',
#        'Density_Ten_Year', 'One_Hundred_Year_Prediction',
#        'Density_One_Hundred_Year'],
#       dtype='object')

# %%
df.shape
# Out:
# (201, 11)

# %%
y=df['Population']
y
# Out:
# 0       649335
# 1      5850342
# 2      7496981
# 3      1701575
# 4       540544
#         ...
# 196     341243
# 197    3278290
# 198    1886198
# 199    2722289
# 200    2860853
# Name: Population, Length: 201, dtype: int64

# %%
X=df[['Country','Area_km','Pop_Density','Yearly_Change',]]
X
# Out:
#      Country  Area_km  Pop_Density  Yearly_Change
# 0          1       30        21645           1.39
# 1          2      700         8358           0.79
# 2          3     1050         7140           0.82
# 3          4      760         2239           3.68
# 4          5      300         1802           1.81
# ..       ...      ...          ...            ...
# 196      197   100250            3           0.65
# 197      198  1553560            2           1.65
# 198      199    62200           30          -1.08
# 199      200    62674           43          -1.35
# 200      201     8870          323          -2.47
#
# [201 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=2529)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((140, 4), (61, 4), (140,), (61,))

# %%
y.shape
# Out:
# (201,)

# %%
y
# Out:
# 0       649335
# 1      5850342
# 2      7496981
# 3      1701575
# 4       540544
#         ...
# 196     341243
# 197    3278290
# 198    1886198
# 199    2722289
# 200    2860853
# Name: Population, Length: 201, dtype: int64

# %%
X.shape
# Out:
# (201, 4)

# %%
X
# Out:
#      Country  Area_km  Pop_Density  Yearly_Change
# 0          1       30        21645           1.39
# 1          2      700         8358           0.79
# 2          3     1050         7140           0.82
# 3          4      760         2239           3.68
# 4          5      300         1802           1.81
# ..       ...      ...          ...            ...
# 196      197   100250            3           0.65
# 197      198  1553560            2           1.65
# 198      199    62200           30          -1.08
# 199      200    62674           43          -1.35
# 200      201     8870          323          -2.47
#
# [201 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=2529)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((140, 4), (61, 4), (140,), (61,))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
y_pred.shape
y_pred
# Out:
# array([ 4.42279173e+07,  7.01335502e+07, -7.19986826e+07, -4.45650613e+07,
#        -1.03205492e+08, -5.30249574e+07,  9.66258752e+06,  5.49938960e+07,
#        -4.67643413e+07,  4.79649308e+07, -2.15324395e+07, -2.32950593e+07,
#         9.64673180e+08,  1.97444176e+07,  6.56580216e+07, -3.77497567e+07,
#         8.21921702e+07,  4.19251340e+07,  4.16402550e+06,  6.22457688e+07,
#         1.91868388e+06,  4.42649100e+07, -9.39304013e+07,  1.55798898e+08,
#         5.96922657e+07,  6.50037708e+07,  6.05376951e+07,  6.65338790e+07,
#         7.83997121e+07,  6.19361927e+07, -4.15358182e+07, -4.72041616e+07,
#         7.05228914e+07,  8.52671283e+07, -8.70967902e+06,  7.25457678e+07,
#        -6.00552837e+07, -3.71362084e+06,  9.38677808e+07,  5.88700691e+07,
#         5.70355978e+07,  6.88638953e+07, -3.83420734e+07,  4.57696837e+07,
#         7.43847625e+07, -5.04140237e+07,  2.73703233e+07,  6.24486058e+07,
#         5.15027984e+07,  8.33063583e+07,  1.45469213e+07,  2.00390030e+07,
#         7.68012257e+07,  8.60071917e+07, -7.39437762e+07,  6.23153257e+07,
#         7.14993887e+06,  1.16152747e+08,  3.45444951e+07, -4.33658300e+07,
#        -2.56534481e+07])

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred)
plt.xlabel("Actual Trades:-")
plt.ylabel("Predicted Trades:-")
plt.title("Actual Trades vs Predicted Trades")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# LASSO REGRESSION
import numpy as np
from sklearn.metrics import mean_squared_error,r2_score 
from sklearn.linear_model import Lasso
model_lasso= Lasso(alpha=0.01)
model_lasso.fit(X_train,y_train)
pred_train_lasso= model_lasso.predict(X_test)

print(mean_squared_error(y_test,pred_train_lasso))
# Out:
# 1.351213918739041e+16

# %%
# RIDGE REGRESSION
from sklearn.linear_model import Ridge 
rr= Ridge(alpha=0.01)
rr.fit(X_train, y_train) 
pred_train_rr= rr.predict(X_train)
print(np.sqrt(mean_squared_error(y_train,pred_train_rr)))
print(r2_score(y_train, pred_train_rr))
# Out:
# 136398011.52132082
# 0.36163348364332426

# %%
# LINEAR REGRESSION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X, y)
model = LinearRegression().fit(X, y)
r_sq = model.score(X, y)
print(f"coefficient of determination: {r_sq}")

print(f"intercept: {model.intercept_}")

print(f"coefficients: {model.coef_}")
# Out:
# coefficient of determination: 0.2605373804722426
# intercept: 94900003.87082134
# coefficients: [-6.70451800e+05  4.11969420e+01 -5.43078294e+03 -1.08465766e+07]

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error,mean_absolute_error
reg_all=linear_model.LinearRegression()
reg_all.fit(X_train,y_train)
y_pred=reg_all.predict(X_test)
Rsquare=reg_all.score(X_test,y_test)
print("Rsquare: %f" %(Rsquare))
print("Intercept: %f" %(reg_all.intercept_))
mse=mean_squared_error(y_test,y_pred)
print("mse: %f" %(mse))
mae = mean_absolute_error(y_test,y_pred)
print("mae: %f" %(mae))
rmse=np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse: %f" %(rmse))
# Out:
# Rsquare: -5.202286
# Intercept: 127100090.104349
# mse: 13512139188049116.000000
# mae: 55359575.897299
# rmse: 116241727.396186
